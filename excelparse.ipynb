# %%
def result(data,plan,fact):
    arr1 = data[plan].to_numpy().astype(type('float', (float,), {}))
    arr2 = data[fact].to_numpy().astype(type('float',(float,), {}))
    result = (arr2 / arr1)
    return result

# %%
# 2010
data_fact = pd.ExcelFile("fact_2010.xlsx").parse(sheet_names="доходы (исполнено)", names=["Name","Index","Budget","BudgetA"], skiprows=2, na_values="NA",index_col="Index")
data_plan = pd.ExcelFile("plan_2010.xlsx").parse(sheet_names="доходы (план)", names=["Name","Index","Budget","BudgetA"], skiprows=2, na_values="NA",index_col="Index")
data_fact = data_fact.drop('BudgetA', 1)
data_plan = data_plan.drop('BudgetA', 1)
data_fact["Name"] = data_fact[(data_fact["Name"].str.isupper() == True)]
data_plan["Name"] = data_plan[(data_plan["Name"].str.isupper() == True)]
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020

# %%
import pandas as pd
import numpy as np
data_fact = pd.ExcelFile("fact_2010.xlsx").parse(sheet_names="доходы (исполнено)", names=["Name","Index","Budget_fact_10","BudgetA"], skiprows=2, na_values="NA",index_col="Index")
data_plan = pd.ExcelFile("plan_2010.xlsx").parse(sheet_names="доходы (план)", names=["Name","Index","Budget_plan_10","BudgetA"], skiprows=2, na_values="NA",index_col="Index")
data_fact = data_fact.drop('BudgetA', 1)
data_plan = data_plan.drop('BudgetA', 1)
data_fact["Name"] = data_fact[(data_fact["Name"].str.isupper() == True)]
data_plan["Name"] = data_plan[(data_plan["Name"].str.isupper() == True)]
data_fact = data_fact.dropna()
data_plan = data_plan.dropna()
data_fact = data_fact.set_index("Name")
data_plan = data_plan.set_index("Name")

# data_plan = data_plan[data_plan["Budget_plan_10"].to_numpy().astype(type('float', (float,), {})) / data_fact["Budget_fact_10"].to_numpy().astype(type('float', (float,), {}))]
# факт делим на план

data_10 = pd.merge(data_plan, data_fact, left_index=True, right_index=True)
arr_2010 = result(data_10, "Budget_fact_10", "Budget_plan_10")
# print(arr_2010)
percent = pd.Series(arr_2010)
data_10 = data_10.assign(percent_10=percent.values).drop(data_10.columns[[0, 1]], axis=1)
print(data_10)
# Out:
#                                                    percent_10
# Name
# НАЛОГОВЫЕ И НЕНАЛОГОВЫЕ ДОХОДЫ                           0.88
# НАЛОГИ НА ПРИБЫЛЬ, ДОХОДЫ                                0.80
# НАЛОГИ НА ТОВАРЫ (РАБОТЫ, УСЛУГИ), РЕАЛИЗУЕМЫЕ ...       0.96
# НАЛОГИ НА СОВОКУПНЫЙ ДОХОД                               0.98
# НАЛОГИ НА ИМУЩЕСТВО                                      1.05
# НАЛОГИ, СБОРЫ И РЕГУЛЯРНЫЕ ПЛАТЕЖИ ЗА ПОЛЬЗОВАН...       1.06
# ГОСУДАРСТВЕННАЯ ПОШЛИНА                                  0.38
# ЗАДОЛЖЕННОСТЬ И ПЕРЕРАСЧЕТЫ ПО ОТМЕНЕННЫМ НАЛОГ...       0.04
# ДОХОДЫ ОТ ИСПОЛЬЗОВАНИЯ ИМУЩЕСТВА, НАХОДЯЩЕГОСЯ...       0.92
# ПЛАТЕЖИ ПРИ ПОЛЬЗОВАНИИ ПРИРОДНЫМИ РЕСУРСАМИ             0.85
# ДОХОДЫ ОТ ОКАЗАНИЯ ПЛАТНЫХ УСЛУГ И КОМПЕНСАЦИИ ...       1.00
# ДОХОДЫ ОТ ПРОДАЖИ МАТЕРИАЛЬНЫХ И НЕМАТЕРИАЛЬНЫХ...       0.80
# АДМИНИСТРАТИВНЫЕ ПЛАТЕЖИ И СБОРЫ                         0.48
# ШТРАФЫ, САНКЦИИ, ВОЗМЕЩЕНИЕ УЩЕРБА                       0.72
# ...

# %%
data_fact = pd.ExcelFile("fact_2011.xlsx").parse(sheet_names="доходы (исполнено)", names=["Name","Index","Budget_fact_11","BudgetA"], skiprows=2, na_values="NA",index_col="Index")
data_plan = pd.ExcelFile("plan_2011.xlsx").parse(sheet_names="доходы (план)", names=["Name","Index","Budget_plan_11","BudgetA"], skiprows=2, na_values="NA",index_col="Index")
data_fact = data_fact.drop('BudgetA', 1)
data_plan = data_plan.drop('BudgetA', 1)
data_fact["Name"] = data_fact[(data_fact["Name"].str.isupper() == True)]
data_plan["Name"] = data_plan[(data_plan["Name"].str.isupper() == True)]
data_fact = data_fact.dropna()
data_plan = data_plan.dropna()
data_fact = data_fact.set_index("Name")
data_plan = data_plan.set_index("Name")

# data_11 = pd.merge(data_plan, data_fact, left_index=True, right_index=True)
# print('2011')

# print(data_11)
data_11 = pd.merge(data_plan, data_fact, left_index=True, right_index=True)
arr_2011 = result(data_11, "Budget_fact_11", "Budget_plan_11")
# print(arr_2010)
percent = pd.Series(arr_2011)
data_11 = data_11.assign(percent_11=percent.values).drop(data_11.columns[[0, 1]], axis=1)
print(data_11)
# arr_2011 = result(data)
# print(result(data))
# Out:
#                                                    percent_11
# Name
# НАЛОГОВЫЕ И НЕНАЛОГОВЫЕ ДОХОДЫ                           0.85
# НАЛОГИ НА ПРИБЫЛЬ, ДОХОДЫ                                0.77
# НАЛОГИ НА ТОВАРЫ (РАБОТЫ, УСЛУГИ), РЕАЛИЗУЕМЫЕ ...       1.08
# НАЛОГИ НА СОВОКУПНЫЙ ДОХОД                               0.92
# НАЛОГИ НА ИМУЩЕСТВО                                      1.09
# НАЛОГИ, СБОРЫ И РЕГУЛЯРНЫЕ ПЛАТЕЖИ ЗА ПОЛЬЗОВАН...       0.78
# ГОСУДАРСТВЕННАЯ ПОШЛИНА                                  0.91
# ЗАДОЛЖЕННОСТЬ И ПЕРЕРАСЧЕТЫ ПО ОТМЕНЕННЫМ НАЛОГ...      -0.03
# ДОХОДЫ ОТ ИСПОЛЬЗОВАНИЯ ИМУЩЕСТВА, НАХОДЯЩЕГОСЯ...       0.91
# ПЛАТЕЖИ ПРИ ПОЛЬЗОВАНИИ ПРИРОДНЫМИ РЕСУРСАМИ             0.78
# ДОХОДЫ ОТ ОКАЗАНИЯ ПЛАТНЫХ УСЛУГ И КОМПЕНСАЦИИ ...       0.96
# ДОХОДЫ ОТ ПРОДАЖИ МАТЕРИАЛЬНЫХ И НЕМАТЕРИАЛЬНЫХ...       0.55
# АДМИНИСТРАТИВНЫЕ ПЛАТЕЖИ И СБОРЫ                         0.22
# ШТРАФЫ, САНКЦИИ, ВОЗМЕЩЕНИЕ УЩЕРБА                       0.71
# ...

# %%
data_plan = pd.ExcelFile('test_plan_2016.xlsx').parse(sheet_name=0,skiprows=1,names=["Name", "Index", "Budget_plan_16", "BudgetA"], na_values="NA")
data_plan = data_plan.drop('BudgetA', 1).drop('Index', 1)
data_plan['Name'] = data_plan['Name'].apply(lambda x: str(x)[2:])
data_plan["Name"] = data_plan[(data_plan["Name"].str.isupper()== True)]
data_plan = data_plan.dropna()
data_plan = data_plan.set_index("Name")

data_fact = pd.ExcelFile("test_2016.xlsx").parse(sheet_name=0, skiprows = 1, names=["Name", "Index", "Budget_fact_16", "BudgetA"], na_values="NA")
data_fact = data_fact.drop('BudgetA', 1).drop('Index',1)
data_fact["Name"] = data_fact[(data_fact["Name"].str.isupper() == True)]
data_fact = data_fact.dropna()
data_fact = data_fact.set_index("Name")
data_fact = data_fact.drop(data_fact.index[6])

data_16 = pd.merge(data_plan, data_fact, left_index=True, right_index=True)
arr_2016 = result(data_16, "Budget_fact_16", "Budget_plan_16")
# print(arr_2010)
percent = pd.Series(arr_2016)
data_16 = data_16.assign(percent_16=percent.values).drop(data_16.columns[[0, 1]], axis=1)
print(data_16)
# Out:
#                                                    percent_16
# Name
# НАЛОГИ НА ПРИБЫЛЬ, ДОХОДЫ                                1.05
# НАЛОГИ НА ТОВАРЫ (РАБОТЫ, УСЛУГИ), РЕАЛИЗУЕМЫЕ ...       0.69
# НАЛОГИ НА СОВОКУПНЫЙ ДОХОД                               1.05
# НАЛОГИ НА ИМУЩЕСТВО                                      1.13
# НАЛОГИ, СБОРЫ И РЕГУЛЯРНЫЕ ПЛАТЕЖИ ЗА ПОЛЬЗОВАН...       1.07
# ДОХОДЫ ОТ ИСПОЛЬЗОВАНИЯ ИМУЩЕСТВА, НАХОДЯЩЕГОСЯ...       1.29
# ПЛАТЕЖИ ПРИ ПОЛЬЗОВАНИИ ПРИРОДНЫМИ РЕСУРСАМИ             0.84
# ДОХОДЫ ОТ ОКАЗАНИЯ ПЛАТНЫХ УСЛУГ (РАБОТ) И КОМП...       0.95
# ДОХОДЫ ОТ ПРОДАЖИ МАТЕРИАЛЬНЫХ И НЕМАТЕРИАЛЬНЫХ...       1.92
# АДМИНИСТРАТИВНЫЕ ПЛАТЕЖИ И СБОРЫ                         2.02
# ШТРАФЫ, САНКЦИИ, ВОЗМЕЩЕНИЕ УЩЕРБА                       0.98
# ПРОЧИЕ НЕНАЛОГОВЫЕ ДОХОДЫ                                3.22
# БЕЗВОЗМЕЗДНЫЕ ПОСТУПЛЕНИЯ                                0.71
# БЕЗВОЗМЕЗДНЫЕ ПОСТУПЛЕНИЯ ОТ ДРУГИХ БЮДЖЕТОВ БЮ...       0.77
# ...

# %%
data_plan = pd.ExcelFile("plan_2012.XLS").parse(sheet_name=1, skiprows=1, names=["Name", "Index", "Budget_plan_12", "BudgetA"], na_values="NA")
data_plan = data_plan.drop('BudgetA', 1).drop('Index', 1)
data_plan["Name"] = data_plan[(data_plan["Name"].str.isupper() == True)]
data_plan = data_plan.dropna()
data_plan = data_plan.set_index("Name")
# ???
data_fact = pd.ExcelFile("test_2012.xlsx").parse(sheet_name=0,skiprows=1, names=["Name", "Index", "Budget_fact_12", "BudgetA"], na_values="NA")
data_fact = data_fact.drop('BudgetA', 1).drop('Index',1)
data_fact["Name"] = data_fact[(data_fact["Name"].str.isupper() == True)]
data_fact = data_fact.dropna()
data_fact = data_fact.set_index("Name")
# data_12 = pd.merge(data_plan, data_fact, left_index=True, right_index=True)
data_12 = pd.merge(data_plan, data_fact, left_index=True, right_index=True)
arr_2012 = result(data_12, "Budget_fact_12", "Budget_plan_12")
# print(arr_2010)
percent = pd.Series(arr_2012)
data_12 = data_12.assign(percent_12=percent.values).drop(data_12.columns[[0, 1]], axis=1)
print(data_12)
# Out:
#                                                    percent_12
# Name
# НАЛОГОВЫЕ И НЕНАЛОГОВЫЕ ДОХОДЫ                           0.98
# НАЛОГИ НА ПРИБЫЛЬ, ДОХОДЫ                                1.03
# НАЛОГИ НА ТОВАРЫ (РАБОТЫ, УСЛУГИ), РЕАЛИЗУЕМЫЕ ...       0.86
# НАЛОГИ НА СОВОКУПНЫЙ ДОХОД                               0.92
# НАЛОГИ НА ИМУЩЕСТВО                                      1.01
# НАЛОГИ, СБОРЫ И РЕГУЛЯРНЫЕ ПЛАТЕЖИ ЗА ПОЛЬЗОВАН...       0.72
# ГОСУДАРСТВЕННАЯ ПОШЛИНА                                  0.96
# ЗАДОЛЖЕННОСТЬ И ПЕРЕРАСЧЕТЫ ПО ОТМЕНЕННЫМ НАЛОГ...       0.06
# ДОХОДЫ ОТ ИСПОЛЬЗОВАНИЯ ИМУЩЕСТВА, НАХОДЯЩЕГОСЯ...       0.79
# ПЛАТЕЖИ ПРИ ПОЛЬЗОВАНИИ ПРИРОДНЫМИ РЕСУРСАМИ             0.97
# ДОХОДЫ ОТ ОКАЗАНИЯ ПЛАТНЫХ УСЛУГ (РАБОТ) И КОМП...       0.96
# ДОХОДЫ ОТ ПРОДАЖИ МАТЕРИАЛЬНЫХ И НЕМАТЕРИАЛЬНЫХ...       0.99
# АДМИНИСТРАТИВНЫЕ ПЛАТЕЖИ И СБОРЫ                         0.17
# ШТРАФЫ, САНКЦИИ, ВОЗМЕЩЕНИЕ УЩЕРБА                       0.46
# ...

# %%
data_plan = pd.ExcelFile("plan_2018.xlsx").parse(sheet_name=1, skiprows=1, names=["Name", "Index", "Budget_plan_18", "BudgetA"], na_values="NA")
data_fact = pd.ExcelFile("fact_2018.xlsx").parse(sheet_name=1, skiprows=1, names=["Name", "Index", "Budget_fact_18", "BudgetA"],  na_values="NA")
data_plan = data_plan.drop('BudgetA', 1).drop('Index', 1)
data_fact = data_fact.drop('BudgetA', 1).drop('Index', 1)
data_fact["Name"] = data_fact[(data_fact["Name"].str.isupper() == True)]
data_plan["Name"] = data_plan[(data_plan["Name"].str.isupper() == True)]
data_plan = data_plan.dropna()
data_fact = data_fact.dropna()
data_fact = data_fact.set_index("Name")
data_plan = data_plan.set_index("Name")
data_18 = pd.merge(data_plan, data_fact, left_index=True, right_index=True)
arr_2018 = result(data_18, "Budget_fact_18", "Budget_plan_18")
# print(arr_2010)
percent = pd.Series(arr_2018)
data_18 = data_18.assign(percent_18=percent.values).drop(data_18.columns[[0, 1]], axis=1)
print(data_18)
# Out:
#                                                    percent_18
# Name
# НАЛОГОВЫЕ И НЕНАЛОГОВЫЕ ДОХОДЫ                           0.84
# НАЛОГИ НА ПРИБЫЛЬ, ДОХОДЫ                                0.79
# НАЛОГИ НА ТОВАРЫ (РАБОТЫ, УСЛУГИ), РЕАЛИЗУЕМЫЕ ...       0.98
# НАЛОГИ НА СОВОКУПНЫЙ ДОХОД                               0.93
# НАЛОГИ НА ИМУЩЕСТВО                                      0.95
# НАЛОГИ, СБОРЫ И РЕГУЛЯРНЫЕ ПЛАТЕЖИ ЗА ПОЛЬЗОВАН...       0.93
# ГОСУДАРСТВЕННАЯ ПОШЛИНА                                  0.88
# ЗАДОЛЖЕННОСТЬ И ПЕРЕРАСЧЕТЫ ПО ОТМЕНЕННЫМ НАЛОГ...       0.04
# ДОХОДЫ ОТ ИСПОЛЬЗОВАНИЯ ИМУЩЕСТВА, НАХОДЯЩЕГОСЯ...       0.99
# ПЛАТЕЖИ ПРИ ПОЛЬЗОВАНИИ ПРИРОДНЫМИ РЕСУРСАМИ             0.57
# ДОХОДЫ ОТ ОКАЗАНИЯ ПЛАТНЫХ УСЛУГ (РАБОТ) И КОМП...       0.61
# ДОХОДЫ ОТ ПРОДАЖИ МАТЕРИАЛЬНЫХ И НЕМАТЕРИАЛЬНЫХ...       1.42
# АДМИНИСТРАТИВНЫЕ ПЛАТЕЖИ И СБОРЫ                         1.49
# ШТРАФЫ, САНКЦИИ, ВОЗМЕЩЕНИЕ УЩЕРБА                       0.94
# ...

# %%
data_plan = pd.ExcelFile("test_plan_2013.xlsx").parse(sheet_name=0, skiprows=1, names=["Name", "Index", "Budget_plan_13", "BudgetA"], na_values="-")
data_plan = data_plan.drop('BudgetA', 1).drop('Index', 1)
data_plan['Name'] = data_plan['Name'].apply(lambda x: str(x)[2:])
data_plan["Name"] = data_plan[(data_plan["Name"].str.isupper() == True)]
data_plan = data_plan.dropna()
data_plan = data_plan.set_index("Name")


data_fact = pd.ExcelFile("test_2013.xlsx").parse(sheet_name=0,skiprows=1, names=["Name", "Index", "Budget_fact_13", "BudgetA"], na_values="-")
data_fact = data_fact.drop('BudgetA', 1).drop('Index',1)
data_fact["Name"] = data_fact[(data_fact["Name"].str.isupper() == True)]
data_fact = data_fact.dropna()
data_fact = data_fact.set_index("Name")
data_13 = pd.merge(data_plan, data_fact, left_index=True, right_index=True)
arr_2013 = result(data_13, "Budget_fact_13", "Budget_plan_13")
# print(arr_2010)
percent = pd.Series(arr_2013)
data_13 = data_13.assign(percent_13=percent.values).drop(data_13.columns[[0, 1]], axis=1)
print(data_13)
# Out:
#                                                    percent_13
# Name
# НАЛОГОВЫЕ И НЕНАЛОГОВЫЕ ДОХОДЫ                           1.19
# НАЛОГИ НА ПРИБЫЛЬ, ДОХОДЫ                                1.32
# НАЛОГИ НА ТОВАРЫ (РАБОТЫ, УСЛУГИ), РЕАЛИЗУЕМЫЕ ...       1.30
# НАЛОГИ НА СОВОКУПНЫЙ ДОХОД                               0.94
# НАЛОГИ НА ИМУЩЕСТВО                                      0.93
# НАЛОГИ, СБОРЫ И РЕГУЛЯРНЫЕ ПЛАТЕЖИ ЗА ПОЛЬЗОВАН...       0.94
# ГОСУДАРСТВЕННАЯ ПОШЛИНА                                  0.75
# ЗАДОЛЖЕННОСТЬ И ПЕРЕРАСЧЕТЫ ПО ОТМЕНЕННЫМ НАЛОГ...       0.00
# ДОХОДЫ ОТ ИСПОЛЬЗОВАНИЯ ИМУЩЕСТВА, НАХОДЯЩЕГОСЯ...       0.87
# ПЛАТЕЖИ ПРИ ПОЛЬЗОВАНИИ ПРИРОДНЫМИ РЕСУРСАМИ             1.05
# ДОХОДЫ ОТ ОКАЗАНИЯ ПЛАТНЫХ УСЛУГ (РАБОТ) И КОМП...       1.13
# ДОХОДЫ ОТ ПРОДАЖИ МАТЕРИАЛЬНЫХ И НЕМАТЕРИАЛЬНЫХ...       1.06
# АДМИНИСТРАТИВНЫЕ ПЛАТЕЖИ И СБОРЫ                         1.33
# ШТРАФЫ, САНКЦИИ, ВОЗМЕЩЕНИЕ УЩЕРБА                       0.78
# ...

# %%
data_plan = pd.ExcelFile("plan_2014.xlsx").parse(sheet_name=1, skiprows=1, names=["Name", "Index", "Budget_plan_14", "BudgetA"], na_values="-")
data_fact = pd.ExcelFile("test.xlsx").parse(sheet_name=0,skiprows = 2, names=["Name", "Index", "Budget_fact_14", "BudgetA"], na_values="-")
data_plan = data_plan[(data_plan["Budget_plan_14"]) != 0.000000e+00]

data_plan = data_plan.drop('BudgetA', 1).drop('Index', 1)
data_plan["Name"] = data_plan[(data_plan["Name"].str.isupper() == True)]
data_plan = data_plan.dropna()
data_plan = data_plan.set_index("Name")


data_fact = data_fact.drop('BudgetA', 1).drop('Index',1)
data_fact["Name"] = data_fact[(data_fact["Name"].str.isupper() == True)]
data_fact = data_fact.dropna()
data_fact = data_fact.set_index("Name")

data_14 = pd.merge(data_plan, data_fact, left_index=True, right_index=True)
arr_2014 = result(data_14, "Budget_fact_14", "Budget_plan_14")
# print(arr_2010)
percent = pd.Series(arr_2014)
data_14 = data_14.assign(percent_14=percent.values).drop(data_14.columns[[0, 1]], axis=1)
print(data_14)
# Out:
#                                                    percent_14
# Name
# НАЛОГОВЫЕ И НЕНАЛОГОВЫЕ ДОХОДЫ                           1.11
# НАЛОГИ НА ПРИБЫЛЬ, ДОХОДЫ                                1.20
# НАЛОГИ НА ТОВАРЫ (РАБОТЫ, УСЛУГИ), РЕАЛИЗУЕМЫЕ ...       0.87
# НАЛОГИ НА СОВОКУПНЫЙ ДОХОД                               1.12
# НАЛОГИ НА ИМУЩЕСТВО                                      1.03
# НАЛОГИ, СБОРЫ И РЕГУЛЯРНЫЕ ПЛАТЕЖИ ЗА ПОЛЬЗОВАН...       1.23
# ГОСУДАРСТВЕННАЯ ПОШЛИНА                                  0.73
# ДОХОДЫ ОТ ИСПОЛЬЗОВАНИЯ ИМУЩЕСТВА, НАХОДЯЩЕГОСЯ...       1.03
# ПЛАТЕЖИ ПРИ ПОЛЬЗОВАНИИ ПРИРОДНЫМИ РЕСУРСАМИ             0.79
# ДОХОДЫ ОТ ОКАЗАНИЯ ПЛАТНЫХ УСЛУГ (РАБОТ) И КОМП...       0.78
# ДОХОДЫ ОТ ПРОДАЖИ МАТЕРИАЛЬНЫХ И НЕМАТЕРИАЛЬНЫХ...       1.06
# АДМИНИСТРАТИВНЫЕ ПЛАТЕЖИ И СБОРЫ                         1.75
# ШТРАФЫ, САНКЦИИ, ВОЗМЕЩЕНИЕ УЩЕРБА                       0.80
# ПРОЧИЕ НЕНАЛОГОВЫЕ ДОХОДЫ                                1.53
# ...

# %%
data_plan = pd.ExcelFile('test_plan_2015.xlsx').parse(sheet_name=0,skiprows=1,names=["Name", "Index", "Budget_plan_15", "BudgetA"], na_values="-")
data_plan = data_plan.drop('BudgetA', 1).drop('Index', 1)
data_plan = data_plan[(data_plan["Budget_plan_15"]) != 0.000000e+00]
data_plan["Name"] = data_plan[(data_plan["Name"].str.isupper() == True)]
data_plan = data_plan.dropna()
data_plan = data_plan.set_index("Name")
# print(data_plan)


data_fact = pd.ExcelFile("test_2015.xlsx").parse(sheet_name=0,skiprows = 2, names=["Name", "Index", "Budget_fact_15", "BudgetA"])
data_fact = data_fact.drop('BudgetA', 1).drop('Index',1)
data_fact["Name"] = data_fact[(data_fact["Name"].str.isupper() == True)]
data_fact = data_fact.dropna()
data_fact = data_fact.set_index("Name")

data_15 = pd.merge(data_plan, data_fact, left_index=True, right_index=True)
arr_2015 = result(data_15, "Budget_fact_15", "Budget_plan_15")
# print(arr_2010)
percent = pd.Series(arr_2015)
data_15 = data_15.assign(percent_15=percent.values).drop(data_15.columns[[0, 1]], axis=1)
print(data_15)
# Out:
#                                                    percent_15
# Name
# НАЛОГИ НА ПРИБЫЛЬ, ДОХОДЫ                                1.09
# НАЛОГИ НА ТОВАРЫ (РАБОТЫ, УСЛУГИ), РЕАЛИЗУЕМЫЕ ...       0.94
# НАЛОГИ НА СОВОКУПНЫЙ ДОХОД                               0.96
# НАЛОГИ НА ИМУЩЕСТВО                                      1.05
# НАЛОГИ, СБОРЫ И РЕГУЛЯРНЫЕ ПЛАТЕЖИ ЗА ПОЛЬЗОВАН...       1.03
# ГОСУДАРСТВЕННАЯ ПОШЛИНА                                  0.80
# ДОХОДЫ ОТ ИСПОЛЬЗОВАНИЯ ИМУЩЕСТВА, НАХОДЯЩЕГОСЯ...       1.09
# ПЛАТЕЖИ ПРИ ПОЛЬЗОВАНИИ ПРИРОДНЫМИ РЕСУРСАМИ             0.72
# ДОХОДЫ ОТ ОКАЗАНИЯ ПЛАТНЫХ УСЛУГ (РАБОТ) И КОМП...       0.90
# ДОХОДЫ ОТ ПРОДАЖИ МАТЕРИАЛЬНЫХ И НЕМАТЕРИАЛЬНЫХ...       1.33
# АДМИНИСТРАТИВНЫЕ ПЛАТЕЖИ И СБОРЫ                         3.11
# ШТРАФЫ, САНКЦИИ, ВОЗМЕЩЕНИЕ УЩЕРБА                       0.89
# ПРОЧИЕ НЕНАЛОГОВЫЕ ДОХОДЫ                                2.89
# БЕЗВОЗМЕЗДНЫЕ ПОСТУПЛЕНИЯ                                0.71
# ...

# %%
data_plan = pd.ExcelFile('test_plan_2017.xlsx').parse(sheet_name=0,skiprows=1,names=["Name", "Index", "Budget_plan_17", "BudgetA"], na_values="-")
data_plan = data_plan.drop('BudgetA', 1).drop('Index', 1)
data_plan['Name'] = data_plan['Name'].apply(lambda x: str(x)[2:])
data_plan["Name"] = data_plan[(data_plan["Name"].str.isupper() == True)]
data_plan = data_plan.dropna()
data_plan = data_plan.set_index("Name")
data_fact = pd.ExcelFile("test_2017.xlsx").parse(sheet_name=0,skiprows = 2, names=["Name", "Index", "Budget_fact_17", "BudgetA"],na_values="-")
data_fact = data_fact.drop('BudgetA', 1).drop('Index',1)
data_fact["Name"] = data_fact[(data_fact["Name"].str.isupper() == True)]
data_fact = data_fact.dropna()
data_fact = data_fact.set_index("Name")
data_17 = pd.merge(data_plan, data_fact, left_index=True, right_index=True)
arr_2017 = result(data_17, "Budget_fact_17", "Budget_plan_17")
# print(arr_2010)
percent = pd.Series(arr_2017)
data_17 = data_17.assign(percent_17=percent.values).drop(data_17.columns[[0, 1]], axis=1)
print(data_17)
# Out:
#                                                    percent_17
# Name
# НАЛОГИ НА ТОВАРЫ (РАБОТЫ, УСЛУГИ), РЕАЛИЗУЕМЫЕ ...       0.85
# НАЛОГИ НА СОВОКУПНЫЙ ДОХОД                               1.01
# НАЛОГИ НА ИМУЩЕСТВО                                      1.06
# НАЛОГИ, СБОРЫ И РЕГУЛЯРНЫЕ ПЛАТЕЖИ ЗА ПОЛЬЗОВАН...       1.13
# ГОСУДАРСТВЕННАЯ ПОШЛИНА                                  1.10
# ДОХОДЫ ОТ ИСПОЛЬЗОВАНИЯ ИМУЩЕСТВА, НАХОДЯЩЕГОСЯ...       1.14
# ПЛАТЕЖИ ПРИ ПОЛЬЗОВАНИИ ПРИРОДНЫМИ РЕСУРСАМИ             1.13
# ДОХОДЫ ОТ ОКАЗАНИЯ ПЛАТНЫХ УСЛУГ (РАБОТ) И КОМП...       0.67
# ДОХОДЫ ОТ ПРОДАЖИ МАТЕРИАЛЬНЫХ И НЕМАТЕРИАЛЬНЫХ...       1.04
# АДМИНИСТРАТИВНЫЕ ПЛАТЕЖИ И СБОРЫ                         1.14
# ШТРАФЫ, САНКЦИИ, ВОЗМЕЩЕНИЕ УЩЕРБА                       1.19
# ПРОЧИЕ НЕНАЛОГОВЫЕ ДОХОДЫ                                0.56
# БЕЗВОЗМЕЗДНЫЕ ПОСТУПЛЕНИЯ                                0.79
# БЕЗВОЗМЕЗДНЫЕ ПОСТУПЛЕНИЯ ОТ ДРУГИХ БЮДЖЕТОВ БЮ...       0.83
# ...

# %%
# 2019 2018 2017 2016 2015 2014 2013 2012 2011 2010
data_plan = pd.ExcelFile('test_plan_2019.xlsx').parse(sheet_name=0,skiprows=1,names=["Name", "Index", "Budget_plan_19", "BudgetA"], na_values="-")
data_plan = data_plan.drop('BudgetA', 1).drop('Index', 1)
# data_plan['Name'] = data_plan['Name'].apply(lambda x: str(x)[2:])
data_plan["Name"] = data_plan[(data_plan["Name"].str.isupper() == True)]
data_plan = data_plan.dropna()
data_plan = data_plan.set_index("Name")
data_fact = pd.ExcelFile("test_2019.xlsx").parse(sheet_name=0,skiprows = 2, names=["Name", "Index", "Budget_fact_19", "BudgetA"],na_values="-")
data_fact = data_fact.drop('BudgetA', 1).drop('Index',1)
data_fact["Name"] = data_fact[(data_fact["Name"].str.isupper() == True)]
data_fact = data_fact.dropna()
data_fact = data_fact.set_index("Name")
data_19 = pd.merge(data_plan, data_fact, left_index=True, right_index=True)
arr_2019 = result(data_19, "Budget_fact_19", "Budget_plan_19")
# print(arr_2010)
percent = pd.Series(arr_2019)
data_19 = data_19.assign(percent_19=percent.values).drop(data_19.columns[[0, 1]], axis=1)
print(data_19)
# Out:
#                                                    percent_19
# Name
# НАЛОГИ НА ТОВАРЫ (РАБОТЫ, УСЛУГИ), РЕАЛИЗУЕМЫЕ ...       0.92
# НАЛОГИ НА СОВОКУПНЫЙ ДОХОД                               0.96
# НАЛОГИ НА ИМУЩЕСТВО                                      0.90
# НАЛОГИ, СБОРЫ И РЕГУЛЯРНЫЕ ПЛАТЕЖИ ЗА ПОЛЬЗОВАН...       1.00
# ГОСУДАРСТВЕННАЯ ПОШЛИНА                                  1.08
# ЗАДОЛЖЕННОСТЬ И ПЕРЕРАСЧЕТЫ ПО ОТМЕНЕННЫМ НАЛОГ...       0.02
# ДОХОДЫ ОТ ИСПОЛЬЗОВАНИЯ ИМУЩЕСТВА, НАХОДЯЩЕГОСЯ...       0.99
# ПЛАТЕЖИ ПРИ ПОЛЬЗОВАНИИ ПРИРОДНЫМИ РЕСУРСАМИ             0.92
# ДОХОДЫ ОТ ОКАЗАНИЯ ПЛАТНЫХ УСЛУГ И КОМПЕНСАЦИИ ...       0.63
# ДОХОДЫ ОТ ПРОДАЖИ МАТЕРИАЛЬНЫХ И НЕМАТЕРИАЛЬНЫХ...       1.54
# АДМИНИСТРАТИВНЫЕ ПЛАТЕЖИ И СБОРЫ                         1.20
# ШТРАФЫ, САНКЦИИ, ВОЗМЕЩЕНИЕ УЩЕРБА                       0.80
# ПРОЧИЕ НЕНАЛОГОВЫЕ ДОХОДЫ                                0.34
# БЕЗВОЗМЕЗДНЫЕ ПОСТУПЛЕНИЯ                                0.95
# ...

# %%
data_plan = pd.ExcelFile('test_plan_2020.xlsx').parse(sheet_name=0,skiprows=1,names=["Name", "Index", "Budget_plan_20", "BudgetA"], na_values="-")
data_plan = data_plan.drop('BudgetA', 1).drop('Index', 1)
# data_plan['Name'] = data_plan['Name'].apply(lambda x: str(x)[2:])
data_plan["Name"] = data_plan[(data_plan["Name"].str.isupper() == True)]
data_plan = data_plan.dropna()
data_plan = data_plan.set_index("Name")
data_fact = pd.ExcelFile("test_2020.xlsx").parse(sheet_name=0,skiprows = 2, names=["Name", "Index", "Budget_fact_20", "BudgetA"],na_values="-")
data_fact = data_fact.drop('BudgetA', 1).drop('Index',1)
data_fact["Name"] = data_fact[(data_fact["Name"].str.isupper() == True)]
data_fact = data_fact.dropna()
data_fact = data_fact.set_index("Name")
data_20 = pd.merge(data_plan, data_fact, left_index=True, right_index=True)
arr_2020 = result(data_20, "Budget_fact_20", "Budget_plan_20")
# print(arr_2010)
percent = pd.Series(arr_2020)
data_20 = data_20.assign(percent_20=percent.values).drop(data_20.columns[[0, 1]], axis=1)
print(data_20)
# Out:
#                                                    percent_20
# Name
# НАЛОГИ НА ТОВАРЫ (РАБОТЫ, УСЛУГИ), РЕАЛИЗУЕМЫЕ ...       1.11
# НАЛОГИ НА СОВОКУПНЫЙ ДОХОД                               0.94
# НАЛОГИ НА ИМУЩЕСТВО                                      0.93
# НАЛОГИ, СБОРЫ И РЕГУЛЯРНЫЕ ПЛАТЕЖИ ЗА ПОЛЬЗОВАН...       1.05
# ГОСУДАРСТВЕННАЯ ПОШЛИНА                                  1.21
# ЗАДОЛЖЕННОСТЬ И ПЕРЕРАСЧЕТЫ ПО ОТМЕНЕННЫМ НАЛОГ...       0.08
# ДОХОДЫ ОТ ИСПОЛЬЗОВАНИЯ ИМУЩЕСТВА, НАХОДЯЩЕГОСЯ...       1.06
# ПЛАТЕЖИ ПРИ ПОЛЬЗОВАНИИ ПРИРОДНЫМИ РЕСУРСАМИ             0.95
# ДОХОДЫ ОТ ОКАЗАНИЯ ПЛАТНЫХ УСЛУГ И КОМПЕНСАЦИИ ...       1.09
# ДОХОДЫ ОТ ПРОДАЖИ МАТЕРИАЛЬНЫХ И НЕМАТЕРИАЛЬНЫХ...       1.84
# АДМИНИСТРАТИВНЫЕ ПЛАТЕЖИ И СБОРЫ                         1.86
# ШТРАФЫ, САНКЦИИ, ВОЗМЕЩЕНИЕ УЩЕРБА                       0.43
# ПРОЧИЕ НЕНАЛОГОВЫЕ ДОХОДЫ                                0.46
# БЕЗВОЗМЕЗДНЫЕ ПОСТУПЛЕНИЯ                                0.74
# ...

# %%
print('2010',arr_2010.shape[0])
print('2011',arr_2011.shape[0])
print('2012',arr_2012.shape[0])
print('2013',arr_2013.shape[0])
print('2014',arr_2014.shape[0])
print('2015',arr_2015.shape[0])
print('2016',arr_2016.shape[0])
print('2017',arr_2017.shape[0])
print('2018',arr_2018.shape[0])
print('2019',arr_2019.shape[0])
print('2020',arr_2020.shape[0])
big_arr = np.concatenate((arr_2011,arr_2012,arr_2013, arr_2014,arr_2015, arr_2016, arr_2017, arr_2018, arr_2019, arr_2020), axis=0)
print(big_arr)
# Out:
# 2010 19
# 2011 18
# 2012 19
# 2013 18
# 2014 18
# 2015 17
# 2016 19
# 2017 15
# 2018 19
# 2019 16
# 2020 18
# [0.8472580589817299 0.7737619007090145 1.0772010170061839
#  0.9224176306702029 1.0898231746909408 0.7788802910333766
#  0.9081003910411549 -0.034121134406020284 0.9111850949139867
#  0.7831559631335044 0.9572982316529473 0.549499399480049
#  0.22072315669743808 0.7067446896011221 1.0260603052349 0.6538004189328227
#  0.6559537007598394 0.6954526837453232 0.981376843153252 1.031757027927647
#  0.8600492042031411 0.9238217520365173 1.0080953506016934
#  0.7233285225271215 0.9640214635281367 0.06277545226431912
#  0.7884270143406068 0.9742226393875841 0.9648656987198133
#  0.9885418701307066 0.1717995581334348 0.46274091644697035
#  1.0536927380771601 0.7459002279640412 0.7418449255480585
#  0.4004505576487229 1.028642069039964 1.1943386259929496
#  1.3234776910228658 1.3019717613784207 0.9433156952917643
#  0.9341375073772888 0.9407308258763607 0.7506811256891555
# ...

# %%
big_data = pd.merge(data_10, data_11, left_index=True, right_index=True)
big_data = pd.merge(big_data, data_12, left_index=True, right_index=True)
big_data = pd.merge(big_data, data_13, left_index=True, right_index=True)
big_data = pd.merge(big_data, data_14, left_index=True, right_index=True)
big_data = pd.merge(big_data, data_15, left_index=True, right_index=True)
big_data = pd.merge(big_data, data_16, left_index=True, right_index=True)
big_data = pd.merge(big_data, data_17, left_index=True, right_index=True)
big_data = pd.merge(big_data, data_18, left_index=True, right_index=True)
big_data = pd.merge(big_data, data_19, left_index=True, right_index=True)
big_data = pd.merge(big_data, data_20, left_index=True, right_index=True)
res = []
for index in range(0, 13):
    res.append(np.std(big_data.iloc[index]))
# print(len(res))
percent = pd.Series(res)
big_data = big_data.assign(std=percent.values)
print(big_data)
# Out:
#                                                    percent_10 percent_11  \
# Name
# НАЛОГИ НА ТОВАРЫ (РАБОТЫ, УСЛУГИ), РЕАЛИЗУЕМЫЕ ...       0.96       1.08
# НАЛОГИ НА СОВОКУПНЫЙ ДОХОД                               0.98       0.92
# НАЛОГИ НА ИМУЩЕСТВО                                      1.05       1.09
# НАЛОГИ, СБОРЫ И РЕГУЛЯРНЫЕ ПЛАТЕЖИ ЗА ПОЛЬЗОВАН...       1.06       0.78
# ДОХОДЫ ОТ ИСПОЛЬЗОВАНИЯ ИМУЩЕСТВА, НАХОДЯЩЕГОСЯ...       0.92       0.91
# ПЛАТЕЖИ ПРИ ПОЛЬЗОВАНИИ ПРИРОДНЫМИ РЕСУРСАМИ             0.85       0.78
# ДОХОДЫ ОТ ПРОДАЖИ МАТЕРИАЛЬНЫХ И НЕМАТЕРИАЛЬНЫХ...       0.80       0.55
# АДМИНИСТРАТИВНЫЕ ПЛАТЕЖИ И СБОРЫ                         0.48       0.22
# ШТРАФЫ, САНКЦИИ, ВОЗМЕЩЕНИЕ УЩЕРБА                       0.72       0.71
# ПРОЧИЕ НЕНАЛОГОВЫЕ ДОХОДЫ                                0.58       1.03
# БЕЗВОЗМЕЗДНЫЕ ПОСТУПЛЕНИЯ                                0.59       0.65
# БЕЗВОЗМЕЗДНЫЕ ПОСТУПЛЕНИЯ ОТ ДРУГИХ БЮДЖЕТОВ БЮ...       0.60       0.66
# ...

# %%
40602782055 * 0.153097
# Out:
# 6216164124.274336

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
data_plan = pd.ExcelFile("test_plan_2015.xlsx").parse(sheet_name=0,skiprows = 2, names=["Name", "Index", "Budget_plan_15", "BudgetA"])
data_plan = data_plan.drop('BudgetA', 1).drop('Index',1)
data_plan["Name"] = data_plan[(data_plan["Name"].str.isupper() == True)]
data_plan = data_plan.dropna()
data_plan = data_plan.set_index("Name")

data_fact = pd.ExcelFile("test_2015.xlsx").parse(sheet_name=0,skiprows = 2, names=["Name", "Index", "Budget_fact_15", "BudgetA"])
data_fact = data_fact.drop('BudgetA', 1).drop('Index',1)
data_fact["Name"] = data_fact[(data_fact["Name"].str.isupper() == True)]
data_fact = data_fact.dropna()
data_fact = data_fact.set_index("Name")

data_19 = pd.merge(data_plan["Budget_plan_15"], big_data["std"], left_index=True, right_index=True)
result = []
# print(data_19)
for index in range(0, 13):
        # План * коэф
    result.append(data_19["Budget_plan_15"].iloc[index] * 1 - big_data["std"].iloc[index])
itog = pd.Series(result)
# new_frame = pd.merge(data_fact["Budget_fact_15"], big_data["std"])
data_19 = data_19.assign(itog=itog.values)

data_19 = pd.merge(data_19, data_fact["Budget_fact_15"], left_index=True, right_index=True)
# print(data_19)

coeff = []
for index in range(0, 13):
    coeff.append(data_19["Budget_fact_15"].iloc[index] / data_19["itog"].iloc[index])
coeff2 = pd.Series(coeff)
data_19 = data_19.assign(coeff2=coeff2.values)
# data_19 = pd.merge(data_19, big_data["std"], left_index=True, right_index=True)
# print(data_19)

itog_data = pd.merge(data_19["std"],data_19["coeff2"],left_index=True, right_index=True)
print(itog_data)
# Out:
#                                                     std  coeff2
# Name
# НАЛОГИ НА ТОВАРЫ (РАБОТЫ, УСЛУГИ), РЕАЛИЗУЕМЫЕ ... 0.15    1.06
# НАЛОГИ НА СОВОКУПНЫЙ ДОХОД                         0.06    1.04
# НАЛОГИ НА ИМУЩЕСТВО                                0.07    0.95
# НАЛОГИ, СБОРЫ И РЕГУЛЯРНЫЕ ПЛАТЕЖИ ЗА ПОЛЬЗОВАН... 0.14    0.97
# ДОХОДЫ ОТ ИСПОЛЬЗОВАНИЯ ИМУЩЕСТВА, НАХОДЯЩЕГОСЯ... 0.13    0.92
# ПЛАТЕЖИ ПРИ ПОЛЬЗОВАНИИ ПРИРОДНЫМИ РЕСУРСАМИ       0.15    1.38
# ДОХОДЫ ОТ ПРОДАЖИ МАТЕРИАЛЬНЫХ И НЕМАТЕРИАЛЬНЫХ... 0.40    0.75
# АДМИНИСТРАТИВНЫЕ ПЛАТЕЖИ И СБОРЫ                   0.82    0.32
# ШТРАФЫ, САНКЦИИ, ВОЗМЕЩЕНИЕ УЩЕРБА                 0.21    1.12
# ПРОЧИЕ НЕНАЛОГОВЫЕ ДОХОДЫ                          0.93    0.35
# БЕЗВОЗМЕЗДНЫЕ ПОСТУПЛЕНИЯ                          0.10    1.41
# БЕЗВОЗМЕЗДНЫЕ ПОСТУПЛЕНИЯ ОТ ДРУГИХ БЮДЖЕТОВ БЮ... 0.11    1.29
# ПРОЧИЕ БЕЗВОЗМЕЗДНЫЕ ПОСТУПЛЕНИЯ                   0.56   11.90
